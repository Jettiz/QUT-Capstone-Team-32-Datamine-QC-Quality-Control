# %%
#importing

import pandas as pd
import numpy as np
import seaborn as sns
import statistics
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from IPython.display import Image, display
from io import StringIO
from sklearn.tree import export_graphviz
import pydot

df = pd.read_csv("QCAnomalyTrainingData.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ANALYTICAL_TYPE                 99999 non-null  object
#  1   STD_LOT_CODE                    99999 non-null  object
#  2   STD_CODE                        99999 non-null  object
#  3   JOB_CODE                        99999 non-null  object
#  4   NUMERIC_FINAL_VALUE             99999 non-null  float64
#  5   ANALYSED_DATE                   99999 non-null  object
#  6   SCHEME_CODE                     99999 non-null  object
#  7   ANALYTE_CODE                    98871 non-null  object
#  8   STANDARD_STATUS                 54675 non-null  object
#  9   PRECISION_STATUS                45315 non-null  object
#  10  INTERNAL_MIN_VALUE              54447 non-null  float64
#  11  INTERNAL_MAX_VALUE              54447 non-null  float64
#  12  INTERNAL_MIN_INCLUSIVE          54677 non-null  object
#  13  INTERNAL_MAX_INCLUSIVE          54677 non-null  object
#  14  INTERNAL_MAX_WARNING_VALUE      36450 non-null  float64
#  15  INTERNAL_MIN_WARNING_VALUE      36450 non-null  float64
#  16  INTERNAL_MIN_WARNING_INCLUSIVE  54677 non-null  object
#  17  INTERNAL_MAX_WARNING_INCLUSIVE  54677 non-null  object
#  18  LIM_REP_VALUE                   99999 non-null  int64
#  19  STAT_DL_VALUE                   99999 non-null  float64
#  20  LIM_REP_DUP_VALUE               99999 non-null  float64
#  21  STAT_DL_DUP_VALUE               99999 non-null  float64
#  22  INTERNAL_TARGET_VALUE           54445 non-null  float64
#  23  PARENT_NUMERIC_FINAL_VALUE      45315 non-null  float64
#  24  UNIT_CODE                       99999 non-null  object
#  25  SPECIFICATION_CODE              54683 non-null  object
#  26  INSTRUMENT_ID                   1 non-null      object
# dtypes: float64(10), int64(1), object(16)
# memory usage: 20.6+ MB
# C:\Users\jknig\AppData\Local\Temp\ipykernel_58388\3781040326.py:15: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("QCAnomalyTrainingData.csv")

# %%
num_col = df.select_dtypes(include=['number'])
correlation_matrix = num_col.corr()
correlation_matrix
# Out:
#                             NUMERIC_FINAL_VALUE  INTERNAL_MIN_VALUE  \
# NUMERIC_FINAL_VALUE                    1.000000            0.971917
# INTERNAL_MIN_VALUE                     0.971917            1.000000
# INTERNAL_MAX_VALUE                     0.971910            0.999999
# INTERNAL_MAX_WARNING_VALUE             0.971829            1.000000
# INTERNAL_MIN_WARNING_VALUE             0.971832            1.000000
# LIM_REP_VALUE                         -0.014033           -0.017727
# STAT_DL_VALUE                         -0.007624            0.000561
# LIM_REP_DUP_VALUE                     -0.012435           -0.015824
# STAT_DL_DUP_VALUE                     -0.007594            0.000603
# INTERNAL_TARGET_VALUE                  0.854144            0.881030
# PARENT_NUMERIC_FINAL_VALUE             0.998033                 NaN
#
#                             INTERNAL_MAX_VALUE  INTERNAL_MAX_WARNING_VALUE  \
# NUMERIC_FINAL_VALUE                   0.971910                    0.971829
# INTERNAL_MIN_VALUE                    0.999999                    1.000000
# INTERNAL_MAX_VALUE                    1.000000                    1.000000
# INTERNAL_MAX_WARNING_VALUE            1.000000                    1.000000
# INTERNAL_MIN_WARNING_VALUE            1.000000                    1.000000
# LIM_REP_VALUE                        -0.017820                   -0.021773
# STAT_DL_VALUE                         0.001642                    0.000713
# LIM_REP_DUP_VALUE                    -0.015989                   -0.019438
# STAT_DL_DUP_VALUE                     0.001685                    0.000764
# INTERNAL_TARGET_VALUE                 0.881020                    0.880619
# PARENT_NUMERIC_FINAL_VALUE                 NaN                         NaN
#
#                             INTERNAL_MIN_WARNING_VALUE  LIM_REP_VALUE  \
# NUMERIC_FINAL_VALUE                           0.971832      -0.014033
# INTERNAL_MIN_VALUE                            1.000000      -0.017727
# INTERNAL_MAX_VALUE                            1.000000      -0.017820
# INTERNAL_MAX_WARNING_VALUE                    1.000000      -0.021773
# INTERNAL_MIN_WARNING_VALUE                    1.000000      -0.021725
# LIM_REP_VALUE                                -0.021725       1.000000
# STAT_DL_VALUE                                 0.000254      -0.105017
# LIM_REP_DUP_VALUE                            -0.019383       0.863807
# STAT_DL_DUP_VALUE                             0.000304      -0.104899
# INTERNAL_TARGET_VALUE                         0.880622      -0.019098
# PARENT_NUMERIC_FINAL_VALUE                         NaN      -0.010001
#
#                             STAT_DL_VALUE  LIM_REP_DUP_VALUE  \
# NUMERIC_FINAL_VALUE             -0.007624          -0.012435
# INTERNAL_MIN_VALUE               0.000561          -0.015824
# INTERNAL_MAX_VALUE               0.001642          -0.015989
# INTERNAL_MAX_WARNING_VALUE       0.000713          -0.019438
# INTERNAL_MIN_WARNING_VALUE       0.000254          -0.019383
# LIM_REP_VALUE                   -0.105017           0.863807
# STAT_DL_VALUE                    1.000000          -0.105292
# LIM_REP_DUP_VALUE               -0.105292           1.000000
# STAT_DL_DUP_VALUE                0.999863          -0.105188
# INTERNAL_TARGET_VALUE            0.002393          -0.017104
# PARENT_NUMERIC_FINAL_VALUE      -0.015039          -0.008772
#
#                             STAT_DL_DUP_VALUE  INTERNAL_TARGET_VALUE  \
# NUMERIC_FINAL_VALUE                 -0.007594               0.854144
# INTERNAL_MIN_VALUE                   0.000603               0.881030
# INTERNAL_MAX_VALUE                   0.001685               0.881020
# INTERNAL_MAX_WARNING_VALUE           0.000764               0.880619
# INTERNAL_MIN_WARNING_VALUE           0.000304               0.880622
# LIM_REP_VALUE                       -0.104899              -0.019098
# STAT_DL_VALUE                        0.999863               0.002393
# LIM_REP_DUP_VALUE                   -0.105188              -0.017104
# STAT_DL_DUP_VALUE                    1.000000               0.002438
# INTERNAL_TARGET_VALUE                0.002438               1.000000
# PARENT_NUMERIC_FINAL_VALUE          -0.015019                    NaN
#
#                             PARENT_NUMERIC_FINAL_VALUE
# NUMERIC_FINAL_VALUE                           0.998033
# INTERNAL_MIN_VALUE                                 NaN
# INTERNAL_MAX_VALUE                                 NaN
# INTERNAL_MAX_WARNING_VALUE                         NaN
# INTERNAL_MIN_WARNING_VALUE                         NaN
# LIM_REP_VALUE                                -0.010001
# STAT_DL_VALUE                                -0.015039
# LIM_REP_DUP_VALUE                            -0.008772
# STAT_DL_DUP_VALUE                            -0.015019
# INTERNAL_TARGET_VALUE                              NaN
# PARENT_NUMERIC_FINAL_VALUE                    1.000000

# %%
df = df[df['ANALYTICAL_TYPE'] == 'Blank']

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17997 entries, 6 to 99998
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ANALYTICAL_TYPE                 17997 non-null  object
#  1   STD_LOT_CODE                    17997 non-null  object
#  2   STD_CODE                        17997 non-null  object
#  3   JOB_CODE                        17997 non-null  object
#  4   NUMERIC_FINAL_VALUE             17997 non-null  float64
#  5   ANALYSED_DATE                   17997 non-null  object
#  6   SCHEME_CODE                     17997 non-null  object
#  7   ANALYTE_CODE                    17831 non-null  object
#  8   STANDARD_STATUS                 17993 non-null  object
#  9   PRECISION_STATUS                0 non-null      object
#  10  INTERNAL_MIN_VALUE              17997 non-null  float64
#  11  INTERNAL_MAX_VALUE              17997 non-null  float64
#  12  INTERNAL_MIN_INCLUSIVE          17997 non-null  object
#  13  INTERNAL_MAX_INCLUSIVE          17997 non-null  object
#  14  INTERNAL_MAX_WARNING_VALUE      0 non-null      float64
#  15  INTERNAL_MIN_WARNING_VALUE      0 non-null      float64
#  16  INTERNAL_MIN_WARNING_INCLUSIVE  17997 non-null  object
#  17  INTERNAL_MAX_WARNING_INCLUSIVE  17997 non-null  object
#  18  LIM_REP_VALUE                   17997 non-null  int64
#  19  STAT_DL_VALUE                   17997 non-null  float64
#  20  LIM_REP_DUP_VALUE               17997 non-null  float64
#  21  STAT_DL_DUP_VALUE               17997 non-null  float64
#  22  INTERNAL_TARGET_VALUE           17997 non-null  float64
#  23  PARENT_NUMERIC_FINAL_VALUE      0 non-null      float64
#  24  UNIT_CODE                       17997 non-null  object
#  25  SPECIFICATION_CODE              17997 non-null  object
#  26  INSTRUMENT_ID                   1 non-null      object
# dtypes: float64(10), int64(1), object(16)
# memory usage: 3.8+ MB

# %%
#Dropping columns and filtering
filtered_df = df.drop(['UNIT_CODE', 'SPECIFICATION_CODE', 'PARENT_NUMERIC_FINAL_VALUE', 'INSTRUMENT_ID', 'INTERNAL_MAX_WARNING_VALUE', 'INTERNAL_MIN_WARNING_VALUE', 'PRECISION_STATUS', 'STD_LOT_CODE', 'STD_CODE'], axis=1, inplace=False)

filtered_df = filtered_df.dropna()

filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17827 entries, 6 to 99998
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ANALYTICAL_TYPE                 17827 non-null  object
#  1   JOB_CODE                        17827 non-null  object
#  2   NUMERIC_FINAL_VALUE             17827 non-null  float64
#  3   ANALYSED_DATE                   17827 non-null  object
#  4   SCHEME_CODE                     17827 non-null  object
#  5   ANALYTE_CODE                    17827 non-null  object
#  6   STANDARD_STATUS                 17827 non-null  object
#  7   INTERNAL_MIN_VALUE              17827 non-null  float64
#  8   INTERNAL_MAX_VALUE              17827 non-null  float64
#  9   INTERNAL_MIN_INCLUSIVE          17827 non-null  object
#  10  INTERNAL_MAX_INCLUSIVE          17827 non-null  object
#  11  INTERNAL_MIN_WARNING_INCLUSIVE  17827 non-null  object
#  12  INTERNAL_MAX_WARNING_INCLUSIVE  17827 non-null  object
#  13  LIM_REP_VALUE                   17827 non-null  int64
#  14  STAT_DL_VALUE                   17827 non-null  float64
#  15  LIM_REP_DUP_VALUE               17827 non-null  float64
#  16  STAT_DL_DUP_VALUE               17827 non-null  float64
#  17  INTERNAL_TARGET_VALUE           17827 non-null  float64
# dtypes: float64(7), int64(1), object(10)
# memory usage: 2.6+ MB

# %%
filtered_df.value_counts()
# Out:
# ANALYTICAL_TYPE  JOB_CODE          NUMERIC_FINAL_VALUE  ANALYSED_DATE  SCHEME_CODE  ANALYTE_CODE  STANDARD_STATUS  INTERNAL_MIN_VALUE  INTERNAL_MAX_VALUE  INTERNAL_MIN_INCLUSIVE  INTERNAL_MAX_INCLUSIVE  INTERNAL_MIN_WARNING_INCLUSIVE  INTERNAL_MAX_WARNING_INCLUSIVE  LIM_REP_VALUE  STAT_DL_VALUE  LIM_REP_DUP_VALUE  STAT_DL_DUP_VALUE  INTERNAL_TARGET_VALUE
# Blank            TSV_LB0003795557  0.009000             51:13.0        GE_IMS40Q12  W             Pass             -0.250              0.250               Y                       Y                       Y                               Y                               15             0.250          22.5               0.250              0.0                      2
#                  TSV_LB0002670477  0.008800             12:47.0        GE_IMS40Q12  TE            Pass             -0.500              0.500               Y                       Y                       Y                               Y                               10             0.125          15.0               0.125              0.0                      2
#                  TSV_LB0005394796  0.004000             34:20.0        GE_IMS40Q12  W             Pass             -0.250              0.250               Y                       Y                       Y                               Y                               15             0.250          22.5               0.250              0.0                      2
#                  TSV_LB0004440213  0.007200             58:18.0        GE_IMS40Q12  BI            Pass             -0.250              0.250               Y                       Y                       Y                               Y                               10             0.100          15.0               0.100              0.0                      2
#                  TSV_LB0005815864  0.005700             30:58.0        GE_IMS40Q12  CE            Pass             -0.125              0.125               Y                       Y                       Y                               Y                               10             0.125          15.0               0.125              0.0                      2
#                                                                                                                                                                                                                                                                                                                                                                        ..
#                  TSV_LB0004328823  0.616667             41:40.0        GE_ICP40Q12  TH            Pass             -25.000             25.000              Y                       Y                       Y                               Y                               10             5.000          15.0               5.000              0.0                      1
#                                    0.690000             04:52.0        GE_ICP40Q12  ZN            Pass             -12.500             12.500              Y                       Y                       Y                               Y                               10             2.500          15.0               2.500              0.0                      1
#                                    0.750000             04:42.0        GE_ICP40Q12  V             Pass             -5.000              5.000               Y                       Y                       Y                               Y                               10             5.000          15.0               5.000              0.0                      1
#                                    0.800000             15:22.0        GE_ICP40Q12  U             Pass             -50.000             50.000              Y                       Y                       Y                               Y                               10             50.000         15.0               50.000             0.0                      1
#                  TSV_LB0016663011  0.335467             35:19.0        GE_IMS40Q12  ZN            Pass             -12.500             12.500              Y                       Y                       Y                               Y                               10             12.500         15.0               12.500             0.0                      1
# Name: count, Length: 17819, dtype: int64

# %%
# importing
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dg = sns.countplot(data=filtered_df, x='STANDARD_STATUS')
plt.show()

# %%
filtered_df.plot(x='ANALYSED_DATE', y='NUMERIC_FINAL_VALUE')
# Out:
# <Axes: xlabel='ANALYSED_DATE'>

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=filtered_df, 
    x='ANALYSED_DATE', 
    y='NUMERIC_FINAL_VALUE', 
    hue='STANDARD_STATUS',
    alpha=0.8
)
plt.show()

# %% [markdown]
# ## CREATING A TEST/TRAIN PARTITION

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17827 entries, 6 to 99998
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ANALYTICAL_TYPE                 17827 non-null  object
#  1   JOB_CODE                        17827 non-null  object
#  2   NUMERIC_FINAL_VALUE             17827 non-null  float64
#  3   ANALYSED_DATE                   17827 non-null  object
#  4   SCHEME_CODE                     17827 non-null  object
#  5   ANALYTE_CODE                    17827 non-null  object
#  6   STANDARD_STATUS                 17827 non-null  object
#  7   INTERNAL_MIN_VALUE              17827 non-null  float64
#  8   INTERNAL_MAX_VALUE              17827 non-null  float64
#  9   INTERNAL_MIN_INCLUSIVE          17827 non-null  object
#  10  INTERNAL_MAX_INCLUSIVE          17827 non-null  object
#  11  INTERNAL_MIN_WARNING_INCLUSIVE  17827 non-null  object
#  12  INTERNAL_MAX_WARNING_INCLUSIVE  17827 non-null  object
#  13  LIM_REP_VALUE                   17827 non-null  int64
#  14  STAT_DL_VALUE                   17827 non-null  float64
#  15  LIM_REP_DUP_VALUE               17827 non-null  float64
#  16  STAT_DL_DUP_VALUE               17827 non-null  float64
#  17  INTERNAL_TARGET_VALUE           17827 non-null  float64
# dtypes: float64(7), int64(1), object(10)
# memory usage: 2.6+ MB

# %%
filtered_df['STANDARD_STATUS'] = filtered_df['STANDARD_STATUS'].fillna(statistics.mode(filtered_df['STANDARD_STATUS']))
filtered_df.info()
"""
print("new: \n -----------")

filtered_df.info()
"""
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17827 entries, 6 to 99998
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ANALYTICAL_TYPE                 17827 non-null  object
#  1   JOB_CODE                        17827 non-null  object
#  2   NUMERIC_FINAL_VALUE             17827 non-null  float64
#  3   ANALYSED_DATE                   17827 non-null  object
#  4   SCHEME_CODE                     17827 non-null  object
#  5   ANALYTE_CODE                    17827 non-null  object
#  6   STANDARD_STATUS                 17827 non-null  object
#  7   INTERNAL_MIN_VALUE              17827 non-null  float64
#  8   INTERNAL_MAX_VALUE              17827 non-null  float64
#  9   INTERNAL_MIN_INCLUSIVE          17827 non-null  object
#  10  INTERNAL_MAX_INCLUSIVE          17827 non-null  object
#  11  INTERNAL_MIN_WARNING_INCLUSIVE  17827 non-null  object
#  12  INTERNAL_MAX_WARNING_INCLUSIVE  17827 non-null  object
#  13  LIM_REP_VALUE                   17827 non-null  int64
#  14  STAT_DL_VALUE                   17827 non-null  float64
#  15  LIM_REP_DUP_VALUE               17827 non-null  float64
#  16  STAT_DL_DUP_VALUE               17827 non-null  float64
#  17  INTERNAL_TARGET_VALUE           17827 non-null  float64
# dtypes: float64(7), int64(1), object(10)
# memory usage: 2.6+ MB
# '\nprint("new: \n -----------")\n\nfiltered_df.info()\n'

# %%
filtered_df.info()

Y = filtered_df["STANDARD_STATUS"]
X = filtered_df.drop(["STANDARD_STATUS"], axis=1)
# X = pd.get_dummies(filtered_df)
feature_names = X.columns



# splitting 

random_state = 10
test_set_size = 0.3 # doing a 30/70 split

X_train, X_test, y_train, y_test = train_test_split(X.values, Y, test_size=test_set_size, stratify=Y, random_state=random_state)

print("Size of training set:", len(X_train))
print("Size of testing set:", len(X_test))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17827 entries, 6 to 99998
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ANALYTICAL_TYPE                 17827 non-null  object
#  1   JOB_CODE                        17827 non-null  object
#  2   NUMERIC_FINAL_VALUE             17827 non-null  float64
#  3   ANALYSED_DATE                   17827 non-null  object
#  4   SCHEME_CODE                     17827 non-null  object
#  5   ANALYTE_CODE                    17827 non-null  object
#  6   STANDARD_STATUS                 17827 non-null  object
#  7   INTERNAL_MIN_VALUE              17827 non-null  float64
#  8   INTERNAL_MAX_VALUE              17827 non-null  float64
#  9   INTERNAL_MIN_INCLUSIVE          17827 non-null  object
#  10  INTERNAL_MAX_INCLUSIVE          17827 non-null  object
#  11  INTERNAL_MIN_WARNING_INCLUSIVE  17827 non-null  object
#  12  INTERNAL_MAX_WARNING_INCLUSIVE  17827 non-null  object
#  13  LIM_REP_VALUE                   17827 non-null  int64
#  14  STAT_DL_VALUE                   17827 non-null  float64
#  15  LIM_REP_DUP_VALUE               17827 non-null  float64
#  16  STAT_DL_DUP_VALUE               17827 non-null  float64
#  17  INTERNAL_TARGET_VALUE           17827 non-null  float64
# dtypes: float64(7), int64(1), object(10)
# memory usage: 2.6+ MB
# Size of training set: 12478
# Size of testing set: 5349

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

print("Bf Scaling\n-=-=-=-=-=-=-")


for i in range(5):
    col = X_train[:,i]
    print("Variable #{}: min {}, max {}, mean {:.2f} and std dev {:.2f}".format(i, min(col), max(col), np.mean(col), np.std(col)))

X_train = scaler.fit_transform (X_train, y_train)

print("Af Scaling\n-=-=-=-=-=-=-")

for i in range(5):
    col = X_train[:,i]
    print("Variable #{}: min {}, max {}, mean {:.2f} and std dev {:.2f}".format(i, min(col), max(col), np.mean(col), np.std(col)))

X_test = scaler.transform(X_test)
# Out:
# Bf Scaling
# -=-=-=-=-=-=-
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 10
#       8 for i in range(5):
#       9     col = X_train[:,i]
# ---> 10     print("Variable #{}: min {}, max {}, mean {:.2f} and std dev {:.2f}".format(i, min(col), max(col), np.mean(col), np.std(col)))
#      12 X_train = scaler.fit_transform (X_train, y_train)
#      14 print("Af Scaling\n-=-=-=-=-=-=-")
#
# File F:\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3504, in mean(a, axis, dtype, out, keepdims, where)
#    3501     else:
#    3502         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3504 return _methods._mean(a, axis=axis, dtype=dtype,
#    3505                       out=out, **kwargs)
#
# File F:\anaconda3\Lib\site-packages\numpy\core\_methods.py:131, in _mean(a, axis, dtype, out, keepdims, where)
#     129         ret = ret.dtype.type(ret / rcount)
#     130 else:
# --> 131     ret = ret / rcount
#     133 return ret
#
# TypeError: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(random_state=random_state)

model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 5
#       1 from sklearn.linear_model import LogisticRegression
#       3 model = LogisticRegression(random_state=random_state)
# ----> 5 model.fit(X_train, y_train)
#
# File F:\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File F:\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1223, in LogisticRegression.fit(self, X, y, sample_weight)
#    1220 else:
#    1221     _dtype = [np.float64, np.float32]
# -> 1223 X, y = self._validate_data(
#    1224     X,
#    1225     y,
#    1226     accept_sparse="csr",
#    1227     dtype=_dtype,
#    1228     order="C",
#    1229     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1230 )
#    1231 check_classification_targets(y)
#    1232 self.classes_ = np.unique(y)
#
# File F:\anaconda3\Lib\site-packages\sklearn\base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File F:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1301, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1296         estimator_name = _check_estimator_name(estimator)
#    1297     raise ValueError(
#    1298         f"{estimator_name} requires y to be passed, but the target y is None"
#    1299     )
# -> 1301 X = check_array(
#    1302     X,
#    1303     accept_sparse=accept_sparse,
#    1304     accept_large_sparse=accept_large_sparse,
#    1305     dtype=dtype,
#    1306     order=order,
#    1307     copy=copy,
#    1308     force_writeable=force_writeable,
#    1309     force_all_finite=force_all_finite,
#    1310     ensure_2d=ensure_2d,
#    1311     allow_nd=allow_nd,
#    1312     ensure_min_samples=ensure_min_samples,
#    1313     ensure_min_features=ensure_min_features,
#    1314     estimator=estimator,
#    1315     input_name="X",
#    1316 )
#    1318 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1320 check_consistent_length(X, y)
#
# File F:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1012, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1010         array = xp.astype(array, dtype, copy=False)
#    1011     else:
# -> 1012         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1013 except ComplexWarning as complex_warning:
#    1014     raise ValueError(
#    1015         "Complex data not supported\n{}\n".format(array)
#    1016     ) from complex_warning
#
# File F:\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py:751, in _asarray_with_order(array, dtype, order, copy, xp, device)
#     749     array = numpy.array(array, order=order, dtype=dtype)
#     750 else:
# --> 751     array = numpy.asarray(array, order=order, dtype=dtype)
#     753 # At this point array is a NumPy ndarray. We convert it to an array
#     754 # container that is consistent with the input's namespace.
#     755 return xp.asarray(array)
#
# ValueError: could not convert string to float: 'Blank'

# %%
from sklearn.metrics import classification_report

print("Train accuracy:", model.score(X_train, y_train))
print("Test accuracy:", model.score(X_test, y_test))
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))

# %%
filtered_df['Prediction'] = model.predict(filtered_df['STANDARD_STATUS'])



filtered_df = pd.get_dummies(filtered_df)
filtered_df.info()




"""
we needed these before so these were snagged from the other notebook.
"""


GROUP_COLUMNS = [
    "SCHEME_CODE",
    "ANALYTE_CODE",
]

filtered_df["TARGET_DEVIATION"] = (
    filtered_df["NUMERIC_FINAL_VALUE"]
    - filtered_df["INTERNAL_FINAL_VALUE"]
)

filtered_df["GROUP_MEDIAN"] = (
    filtered_df.groupby(GROUP_COLUMNS)["NUMERIC_FINAL_VALUE"].transform("median")
)

filtered_df["ABS_MEDIAN_DEVIATION"] = (
    filtered_df["NUMERIC_FINAL_VALUE"]
    - filtered_df["GROUP_MEDIAN"]
).abs()

filtered_df["GROUP_MAD"] = (
    filtered_df.groupby(GROUP_COLUMNS)["ABS_MEDIAN_DEVIATION"].transform("median")
)

# drift report

filtered_df["ROLL_MEDIAN"] = (
    filtered_df.groupby(GROUP_COLUMNS)["NUMERIC_FINAL_VALUE"]
    .transform(
        lambda values: values.rolling(
            window=10,
            min_periods=3
        ).median()
    )
)

filtered_df["ROLLING_CHANGE"] = (
    filtered_df["ROLLING_MEDIAN"]
    - filtered_df["GROUP_MEDIAN"]
)


display(analysis_df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 filtered_df['Prediction'] = model.predict(filtered_df['STANDARD_STATUS'])
#       5 filtered_df = pd.get_dummies(filtered_df)
#       6 filtered_df.info()
#
# NameError: name 'model' is not defined
