# %%
# read in the data from the excel file  "QC Anomaly Training Data.xlsx" and show the first 10 rows
# you have to  get data from the sheet called  'STD-BLK-SPK Assessment' and make a data frame from the sheet 'REP-DUP assessment'ArithmeticError
import pandas as pd
file_path = "data/QC Anomaly Training Data.xlsx"

# read the data from the specified sheet into a DataFrame
df_1 = pd.read_excel(file_path, sheet_name='STD-BLK-SPK Assessment')
df_2 = pd.read_excel(file_path, sheet_name='REP-DUP assessment')
# show the first 10 rows of the DataFrame
df_1.head(10)
# Out:
#   ANALYTICAL_TYPE STD_LOT_CODE   STD_CODE          JOB_CODE  \
# 0        Standard    OREAS_905  OREAS_905  TSV_LB0016663011
# 1        Standard    OREAS_905  OREAS_905  TSV_LB0016663011
# 2       Replicate       Sample     Sample  TSV_LB0016663011
# 3       Replicate       Sample     Sample  TSV_LB0016663011
# 4        Standard    OREAS_905  OREAS_905  TSV_LB0016663011
# 5        Standard    OREAS_905  OREAS_905  TSV_LB0016663011
# 6           Blank    TSV_BLANK  TSV_BLANK  TSV_LB0016663011
# 7        Standard    OREAS_905  OREAS_905  TSV_LB0016663011
# 8        Standard    OREAS_905  OREAS_905  TSV_LB0016663011
# 9       Replicate       Sample     Sample  TSV_LB0016663011
#
#    NUMERIC_FINAL_VALUE       ANALYSED_DATE  SCHEME_CODE ANALYTE_CODE  \
# 0            35.927171 2021-11-22 16:37:52  GE_IMS40Q12           PB
# 1            55.639610 2021-11-22 16:37:52  GE_IMS40Q12           PB
# 2          1492.268392 2021-11-22 16:37:52  GE_IMS40Q12           PB
# ...

# %%
df_2.head(10)
# Out:
#   ANALYTICAL_TYPE  SCHEME_CODE ANALYTE_CODE UNIT_CODE           ANALYSED_DATE  \
# 0       Replicate  GE_IMS40Q12           CU     MG_KG 2021-07-20 14:17:36.000
# 1       Replicate  GE_ICP40Q12           CR     MG_KG 2021-09-02 15:51:13.000
# 2       Replicate  GE_ICP40Q12           CR     MG_KG 2021-04-28 03:04:33.000
# 3       Replicate  GE_ICP40Q12           BI     MG_KG 2021-03-22 06:43:40.000
# 4       Replicate  GE_ICP40Q12           BI     MG_KG 2020-12-14 07:39:45.540
# 5       Replicate  GE_ICP40Q12           BI     MG_KG 2021-06-22 12:45:29.000
# 6       Replicate  GE_ICP40Q12           BI     MG_KG 2020-11-30 11:33:54.000
# 7       Replicate  GE_ICP40Q12           BI     MG_KG 2021-04-12 07:43:54.450
# 8       Replicate  GE_ICP40Q12           BI     MG_KG 2021-04-12 07:40:31.504
# 9       Replicate  GE_ICP40Q12           BI     MG_KG 2021-04-12 07:40:27.793
#
#    NUMERIC_FINAL_VALUE  PARENT_NUMERIC_FINAL_VALUE PRECISION_STATUS  \
# ...

# %%
df_1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ANALYTICAL_TYPE                 99999 non-null  str
#  1   STD_LOT_CODE                    99999 non-null  str
#  2   STD_CODE                        99999 non-null  str
#  3   JOB_CODE                        99999 non-null  str
#  4   NUMERIC_FINAL_VALUE             99999 non-null  float64
#  5   ANALYSED_DATE                   99999 non-null  datetime64[us]
#  6   SCHEME_CODE                     99999 non-null  str
#  7   ANALYTE_CODE                    98871 non-null  str
#  8   STANDARD_STATUS                 54675 non-null  str
#  9   PRECISION_STATUS                45315 non-null  str
#  10  INTERNAL_MIN_VALUE              54447 non-null  float64
#  11  INTERNAL_MAX_VALUE              54447 non-null  float64
# ...

# %%
df['STANDARD_STATUS'].unique()

df['ANALYTICAL_TYPE'].unique()
# Out:
# <ArrowStringArray>
# ['Standard', 'Blank']
# Length: 2, dtype: str

# %%
df_1['ANALYTICAL_TYPE'].unique()
# Out:
# <ArrowStringArray>
# ['Standard', 'Replicate', 'Blank', 'Duplicate']
# Length: 4, dtype: str

# %%
df_2['ANALYTICAL_TYPE'].unique()
# Out:
# <ArrowStringArray>
# ['Replicate', 'Duplicate']
# Length: 2, dtype: str

# %%
df[df['ANALYTICAL_TYPE']== 'Blank'].head(10)
