# %% [markdown]
# # Drift Detection — Control Sample (LCS) Analysis
#
# Detects **gradual drift** in laboratory control sample measurements for a given `STD_LOT_CODE`.
#
# **Method**
# For each analyte within the lot:
# 1. Measurements are sorted chronologically.
# 2. Each value is normalised against the warning bounds:
#    `norm_dev = (value − target) / (warning_bound − target)`
#    where `warning_bound` is `INTERNAL_MAX_WARNING_VALUE` when value ≥ target, else `INTERNAL_MIN_WARNING_VALUE`.
#    A score of **0** means exactly on target; **±1** means at the warning boundary.
# 3. A rolling mean of `norm_dev` is computed.
# 4. **Drift is flagged** when the rolling mean exceeds `DRIFT_THRESHOLD` in magnitude for at least `CONSECUTIVE_REQUIRED` consecutive observations.
#
# **Outputs per analyte**
# - `drift_detected` — boolean flag
# - `drift_direction` — `Upper` (trending high) or `Lower` (trending low)
# - `drift_start` — timestamp of the first observation in the drift sequence
# - `severity_score` — absolute rolling mean at the last observation (0 = on target, 1 = at warning bound)
# - Time-series plot

# %%
from pathlib import Path
import warnings

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.lines import Line2D

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 120)
pd.set_option("display.width", 160)

# %% [markdown]
# ## 1. Load Data

# %%
df = pd.read_csv("Data/raw/ResultSet.csv")
df.columns = [c.strip().upper() for c in df.columns]

for col in ["NUMERIC_FINAL_VALUE", "INTERNAL_TARGET_VALUE",
            "INTERNAL_MAX_WARNING_VALUE", "INTERNAL_MIN_WARNING_VALUE",
            "INTERNAL_MAX_VALUE", "INTERNAL_MIN_VALUE"]:
    df[col] = pd.to_numeric(df[col], errors="coerce")

df["ANALYSED_DATE"] = pd.to_datetime(df["ANALYSED_DATE"], errors="coerce")

print(f"Loaded {len(df):,} rows")
print("Available STD_LOT_CODEs:")
print(df[df["ANALYTICAL_TYPE"] == "Standard"]["STD_LOT_CODE"].value_counts().to_string())
# Out:
# Loaded 99,999 rows
# Available STD_LOT_CODEs:
# STD_LOT_CODE
# Sample        6958
# OREAS_905     5661
# OREAS_62F     5551
# OREAS_501C    5410
# OREAS_503C    4305
# OREAS_624     4299
# OREAS_522     1122
# OREAS_139     1013
# OREAS_908      735
# OREAS_524      519
# OREAS_503D     225
# OREAS_351      205
# OREAS_20A      164
# OREAS_98       157
# OREAS_623      136
# OREAS_621       61
# OREAS_505       58
# OREAS_520       26
# OREAS_136       25
# OREAS_38        21
# OREAS_45F       10
# OREAS_45H       10
# OREAS_622       10
# OREAS_605        6

# %%
display(df[df["ANALYTICAL_TYPE"] == "Standard"])
# Out:
#       ANALYTICAL_TYPE STD_LOT_CODE    STD_CODE          JOB_CODE  NUMERIC_FINAL_VALUE       ANALYSED_DATE  SCHEME_CODE ANALYTE_CODE STANDARD_STATUS  \
# 0            Standard    OREAS_905   OREAS_905  TSV_LB0016663011            35.927171 2021-11-22 16:37:52  GE_IMS40Q12           PB    UpperFailure
# 1            Standard    OREAS_905   OREAS_905  TSV_LB0016663011            55.639610 2021-11-22 16:37:52  GE_IMS40Q12           PB    UpperFailure
# 4            Standard    OREAS_905   OREAS_905  TSV_LB0016663011            11.742601 2021-11-22 16:37:33  GE_IMS40Q12           NI    UpperWarning
# 5            Standard    OREAS_905   OREAS_905  TSV_LB0016663011            12.236060 2021-11-22 16:37:33  GE_IMS40Q12           NI    UpperFailure
# 7            Standard    OREAS_905   OREAS_905  TSV_LB0016663011          1501.882410 2021-11-22 16:35:49  GE_IMS40Q12           CU            Pass
# ...               ...          ...         ...               ...                  ...                 ...          ...          ...             ...
# 99989        Standard    OREAS_624   OREAS_624  TSV_LB0002628992            35.660377 2020-06-26 02:50:23  GE_IMS40Q12           SE    UpperWarning
# 99994        Standard   OREAS_501C  OREAS_501C  TSV_LB0002628992            24.835165 2020-06-26 02:40:42  GE_IMS40Q12           AS            Pass
# 99995        Standard   OREAS_501C  OREAS_501C  TSV_LB0002628992             2.263736 2020-06-26 02:40:42  GE_IMS40Q12           SE            Pass
# 99996        Standard   OREAS_501C  OREAS_501C  TSV_LB0002628992             0.675824 2020-06-26 02:40:42  GE_IMS40Q12           BI            Pass
# 99997        Standard   OREAS_501C  OREAS_501C  TSV_LB0002628992             0.259341 2020-06-26 02:40:42  GE_IMS40Q12           TE            Pass
#
#       PRECISION_STATUS  INTERNAL_MIN_VALUE  INTERNAL_MAX_VALUE INTERNAL_MIN_INCLUSIVE INTERNAL_MAX_INCLUSIVE  INTERNAL_MAX_WARNING_VALUE  \
# 0                  NaN           26.110560           34.689440                      Y                      Y                   33.120800
# 1                  NaN           26.110560           34.689440                      Y                      Y                   33.120800
# 4                  NaN            7.336260           11.743740                      Y                      Y                   10.937610
# 5                  NaN            7.336260           11.743740                      Y                      Y                   10.937610
# 7                  NaN         1379.700000         1686.300000                      Y                      Y                 1630.192200
# ...                ...                 ...                 ...                    ...                    ...                         ...
# 99989              NaN           22.090390           38.109610                      Y                      Y                   35.180880
# 99994              NaN           21.010490           26.789510                      Y                      Y                   25.733130
# 99995              NaN           -3.137085            7.277085                      Y                      Y                    5.372892
# 99996              NaN            0.521019            0.858981                      Y                      Y                    0.797157
# 99997              NaN            0.100000            0.400000                      Y                      Y                    0.345150
#
#        INTERNAL_MIN_WARNING_VALUE INTERNAL_MIN_WARNING_INCLUSIVE INTERNAL_MAX_WARNING_INCLUSIVE  LIM_REP_VALUE  STAT_DL_VALUE  LIM_REP_DUP_VALUE  \
# 0                       27.679200                              Y                              Y             10          1.250               15.0
# 1                       27.679200                              Y                              Y             10          1.250               15.0
# 4                        8.142390                              Y                              Y             10          5.000               15.0
# 5                        8.142390                              Y                              Y             10          5.000               15.0
# 7                     1435.807800                              Y                              Y             10          5.000               15.0
# ...                           ...                            ...                            ...            ...            ...                ...
# 99989                   25.019120                              Y                              Y             10          5.000               15.0
# 99994                   22.066870                              Y                              Y             10          2.500               15.0
# 99995                   -1.232892                              Y                              Y             10          5.000               15.0
# 99996                    0.582843                              Y                              Y             10          0.100               15.0
# 99997                    0.154850                              Y                              Y             10          0.125               15.0
#
#        STAT_DL_DUP_VALUE  INTERNAL_TARGET_VALUE  PARENT_NUMERIC_FINAL_VALUE UNIT_CODE SPECIFICATION_CODE INSTRUMENT_ID
# 0                  1.250                  30.40                         NaN     MG_KG          OREAS_905           NaN
# 1                  1.250                  30.40                         NaN     MG_KG          OREAS_905           NaN
# TSV_LB0002741340     16
# TSV_LB0013196003     14
# TSV_LB0002629103     14
# TSV_LB0015231091     12
# TSV_LB0016663011     10
# TSV_LB0011555742      8
# TSV_LB0009234203      4
# TSV_LB0006906893      4
# TSV_LB0004773102      4
# TSV_LB0003291263      4
# TSV_LB0004839668      3
# TSV_LB0011005475      2
# TSV_LB0010012124      2
# TSV_LB0009932202      2
# TSV_LB0009506639      2
# TSV_LB0008819102      2
# TSV_LB0008615027      2
# TSV_LB0006370189      2
# TSV_LB0006369440      2
# TSV_LB0005925591      2
# TSV_LB0005816683      2
# TSV_LB0005652296      2
# TSV_LB0005205716      2
# TSV_LB0004622664      2
# TSV_LB0004521920      2
# TSV_LB0004233086      2
# TSV_LB0003958542      2
# TSV_LB0003787326      2
# TSV_LB0003617921      2
# TSV_LB0003617711      2
# TSV_LB0003357004      2
# TSV_LB0003119185      2
# TSV_LB0002829499      2
# TSV_LB0007354072      1

# %% [markdown]
# ## 2. Configuration
#
# Set `STD_LOT_CODE` to the lot you want to analyse.
# Tune the drift parameters as needed.

# %%
# ── INPUT ────────────────────────────────────────────────────────────────────
STD_LOT_CODE = "OREAS_905"   # change to any STD_LOT_CODE from the list above
JOB_CODE = 'TSV_LB0005186144'

# ── DRIFT PARAMETERS ─────────────────────────────────────────────────────────
ROLLING_WINDOW     = 10   # number of observations for the rolling mean
DRIFT_THRESHOLD    = 0.5  # fraction of the way from target to warning bound
CONSECUTIVE_REQUIRED = 3  # how many consecutive rolling-mean breaches = drift

# %%
df[(df["ANALYTICAL_TYPE"] == "Standard") & (df["STD_LOT_CODE"] == STD_LOT_CODE) & (df["JOB_CODE"] == JOB_CODE)]["JOB_CODE"].value_counts()
# Out:
# JOB_CODE
# TSV_LB0005186144    172
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Drift Detection

# %%
def detect_drift(df: pd.DataFrame,
                 std_lot_code: str,
                 job_code : str,
                 rolling_window: int = 10,
                 drift_threshold: float = 0.5,
                 consecutive_required: int = 3) -> tuple[pd.DataFrame, dict]:
    """
    Detect drift for all analytes within a given STD_LOT_CODE.

    Returns
    -------
    summary : DataFrame   — one row per analyte with drift results
    analyte_data : dict   — {analyte: per-observation DataFrame} for plotting
    """
    required_cols = [
        "ANALYTICAL_TYPE", "STD_LOT_CODE", "ANALYTE_CODE", "ANALYSED_DATE",
        "NUMERIC_FINAL_VALUE", "INTERNAL_TARGET_VALUE",
        "INTERNAL_MAX_WARNING_VALUE", "INTERNAL_MIN_WARNING_VALUE",
    ]

    lot_df = (
        df[
            (df["ANALYTICAL_TYPE"] == "Standard") &
            (df["STD_LOT_CODE"] == std_lot_code) &
            (df["JOB_CODE"] == job_code)
        ]
        .dropna(subset=required_cols)
        .copy()
    )

    if lot_df.empty:
        raise ValueError(f"No Standard rows found for STD_LOT_CODE='{std_lot_code}'")

    summary_rows = []
    analyte_data = {}

    for analyte, adf in lot_df.groupby("ANALYTE_CODE"):
        adf = adf.sort_values("ANALYSED_DATE").reset_index(drop=True)

        target   = adf["INTERNAL_TARGET_VALUE"]
        max_warn = adf["INTERNAL_MAX_WARNING_VALUE"]
        min_warn = adf["INTERNAL_MIN_WARNING_VALUE"]
        value    = adf["NUMERIC_FINAL_VALUE"]

        upper_range = (max_warn - target).replace(0, np.nan)
        lower_range = (target - min_warn).replace(0, np.nan)

        # Positive norm_dev = drifting high; negative = drifting low
        adf["norm_dev"] = np.where(
            value >= target,
            (value - target) / upper_range,
            (value - target) / lower_range,   # negative when below target
        )

        win = min(rolling_window, len(adf))
        adf["rolling_norm_dev"] = (
            adf["norm_dev"]
            .rolling(window=win, min_periods=max(1, win // 2))
            .mean()
        )

        # ── Find first run of `consecutive_required` breaches ────────────────
        drift_detected  = False
        drift_direction = None
        drift_start     = pd.NaT
        run_start_idx   = None
        run_len         = 0

        for i, rnd in enumerate(adf["rolling_norm_dev"]):
            if pd.isna(rnd):
                run_len = 0
                run_start_idx = None
                continue

            if abs(rnd) >= drift_threshold:
                if run_len == 0:
                    run_start_idx = i
                run_len += 1
                if run_len >= consecutive_required and not drift_detected:
                    drift_detected  = True
                    drift_direction = "Upper" if rnd > 0 else "Lower"
                    drift_start     = adf.loc[run_start_idx, "ANALYSED_DATE"]
            else:
                run_len = 0
                run_start_idx = None

        last_rnd = adf["rolling_norm_dev"].dropna()
        severity_score = float(abs(last_rnd.iloc[-1])) if not last_rnd.empty else np.nan

        # ── First warning / failure dates from STANDARD_STATUS ───────────────
        if "STANDARD_STATUS" in adf.columns:
            warn_mask = (
                adf["STANDARD_STATUS"].str.contains("Warning", na=False) &
                ~adf["STANDARD_STATUS"].str.contains("Ignored", na=False)
            )
            fail_mask = (
                adf["STANDARD_STATUS"].str.contains("Failure", na=False) &
                ~adf["STANDARD_STATUS"].str.contains("Ignored", na=False)
            )
            first_warning_date = adf.loc[warn_mask, "ANALYSED_DATE"].min() if warn_mask.any() else pd.NaT
            first_failure_date = adf.loc[fail_mask, "ANALYSED_DATE"].min() if fail_mask.any() else pd.NaT
        else:
            first_warning_date = pd.NaT
            first_failure_date = pd.NaT

        summary_rows.append({
            "ANALYTE_CODE"      : analyte,
            "drift_detected"    : drift_detected,
            "drift_direction"   : drift_direction,
            "drift_start"       : drift_start,
            "severity_score"    : round(severity_score, 4),
            "first_warning_date": first_warning_date,
            "first_failure_date": first_failure_date,
            "n_observations"    : len(adf),
        })
        analyte_data[analyte] = adf

    summary = (
        pd.DataFrame(summary_rows)
        .sort_values(["drift_detected", "severity_score"], ascending=[False, False])
        .reset_index(drop=True)
    )
    return summary, analyte_data

# %% [markdown]
# ## 4. Run & Summary

# %%
summary, analyte_data = detect_drift(
    df,
    std_lot_code        = STD_LOT_CODE,
    rolling_window      = ROLLING_WINDOW,
    drift_threshold     = DRIFT_THRESHOLD,
    job_code            = JOB_CODE,
    consecutive_required= CONSECUTIVE_REQUIRED,
)

n_drifting = summary["drift_detected"].sum()
print(f"STD_LOT_CODE     : {STD_LOT_CODE}")
print(f"Analytes checked : {len(summary)}")
print(f"Drift detected   : {n_drifting}")
print()

def _fmt_dt(v):
    return v.strftime("%Y-%m-%d") if pd.notna(v) else "—"

def _style_row(row):
    if row["drift_detected"]:
        color = "#ffd6d6" if row["severity_score"] >= 1.0 else "#fff0cc"
    elif pd.notna(row["first_failure_date"]):
        color = "#ffe0e0"
    elif pd.notna(row["first_warning_date"]):
        color = "#fff8e1"
    else:
        color = ""
    return [f"background-color: {color}" if color else "" for _ in row]

display(
    summary.style
    .apply(_style_row, axis=1)
    .format({
        "severity_score"    : "{:.4f}",
        "drift_start"       : _fmt_dt,
        "first_warning_date": _fmt_dt,
        "first_failure_date": _fmt_dt,
    })
    .set_caption(f"Drift summary — {STD_LOT_CODE}")
)
# Out:
# STD_LOT_CODE     : OREAS_905
# Analytes checked : 57
# Drift detected   : 13
# <style type="text/css">
# #T_2c374_row0_col0, #T_2c374_row0_col1, #T_2c374_row0_col2, #T_2c374_row0_col3, #T_2c374_row0_col4, #T_2c374_row0_col5, #T_2c374_row0_col6, #T_2c374_row0_col7, #T_2c374_row1_col0, #T_2c374_row1_col1, #T_2c374_row1_col2, #T_2c374_row1_col3, #T_2c374_row1_col4, #T_2c374_row1_col5, #T_2c374_row1_col6, #T_2c374_row1_col7, #T_2c374_row2_col0, #T_2c374_row2_col1, #T_2c374_row2_col2, #T_2c374_row2_col3, #T_2c374_row2_col4, #T_2c374_row2_col5, #T_2c374_row2_col6, #T_2c374_row2_col7, #T_2c374_row3_col0, #T_2c374_row3_col1, #T_2c374_row3_col2, #T_2c374_row3_col3, #T_2c374_row3_col4, #T_2c374_row3_col5, #T_2c374_row3_col6, #T_2c374_row3_col7, #T_2c374_row4_col0, #T_2c374_row4_col1, #T_2c374_row4_col2, #T_2c374_row4_col3, #T_2c374_row4_col4, #T_2c374_row4_col5, #T_2c374_row4_col6, #T_2c374_row4_col7, #T_2c374_row5_col0, #T_2c374_row5_col1, #T_2c374_row5_col2, #T_2c374_row5_col3, #T_2c374_row5_col4, #T_2c374_row5_col5, #T_2c374_row5_col6, #T_2c374_row5_col7, #T_2c374_row6_col0, #T_2c374_row6_col1, #T_2c374_row6_col2, #T_2c374_row6_col3, #T_2c374_row6_col4, #T_2c374_row6_col5, #T_2c374_row6_col6, #T_2c374_row6_col7, #T_2c374_row7_col0, #T_2c374_row7_col1, #T_2c374_row7_col2, #T_2c374_row7_col3, #T_2c374_row7_col4, #T_2c374_row7_col5, #T_2c374_row7_col6, #T_2c374_row7_col7 {
#   background-color: #ffd6d6;
# }
# #T_2c374_row8_col0, #T_2c374_row8_col1, #T_2c374_row8_col2, #T_2c374_row8_col3, #T_2c374_row8_col4, #T_2c374_row8_col5, #T_2c374_row8_col6, #T_2c374_row8_col7, #T_2c374_row9_col0, #T_2c374_row9_col1, #T_2c374_row9_col2, #T_2c374_row9_col3, #T_2c374_row9_col4, #T_2c374_row9_col5, #T_2c374_row9_col6, #T_2c374_row9_col7, #T_2c374_row10_col0, #T_2c374_row10_col1, #T_2c374_row10_col2, #T_2c374_row10_col3, #T_2c
col7, #T_2c374_row46_col0, #T_2c374_row46_col1, #T_2c374_row46_col2, #T_2c374_row46_col3, #T_2c374_row46_col4, #T_2c374_row46_col5, #T_2c374_row46_col6, #T_2c374_row46_col7, #T_2c374_row47_col0, #T_2c374_row47_col1, #T_2c374_row47_col2, #T_2c374_row47_col3, #T_2c374_row47_col4, #T_2c374_row47_col5, #T_2c374_row47_col6, #T_2c374_row47_col7 {
#   background-color: #fff8e1;
# }
# #T_2c374_row24_col0, #T_2c374_row24_col1, #T_2c374_row24_col2, #T_2c374_row24_col3, #T_2c374_row24_col4, #T_2c374_row24_col5, #T_2c374_row24_col6, #T_2c374_row24_col7, #T_2c374_row26_col0, #T_2c374_row26_col1, #T_2c374_row26_col2, #T_2c374_row26_col3, #T_2c374_row26_col4, #T_2c374_row26_col5, #T_2c374_row26_col6, #T_2c374_row26_col7, #T_2c374_row32_col0, #T_2c374_row32_col1, #T_2c374_row32_col2, #T_2c374_row32_col3, #T_2c374_row32_col4, #T_2c374_row32_col5, #T_2c374_row32_col6, #T_2c374_row32_col7, #T_2c374_row55_col0, #T_2c374_row55_col1, #T_2c374_row55_col2, #T_2c374_row55_col3, #T_2c374_row55_col4, #T_2c374_row55_col5, #T_2c374_row55_col6, #T_2c374_row55_col7 {
#   background-color: #ffe0e0;
# }
# </style>
# <table id="T_2c374">
#   <caption>Drift summary — OREAS_905</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c374_level0_col0" class="col_heading level0 col0" >ANALYTE_CODE</th>
#       <th id="T_2c374_level0_col1" class="col_heading level0 col1" >drift_detected</th>
#       <th id="T_2c374_level0_col2" class="col_heading level0 col2" >drift_direction</th>
#       <th id="T_2c374_level0_col3" class="col_heading level0 col3" >drift_start</th>
#       <th id="T_2c374_level0_col4" class="col_heading level0 col4" >severity_score</th>
#       <th id="T_2c374_level0_col5" class="col_heading level0 col5" >first_warning_date</th>
#       <th id="T_2c374_level0_col6" class="col_heading level0 col6" >first_failure_date</th>
#       <th id="T_2c374_level0_col7" class="col_heading level0 col7" >n_observations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c374_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2c374_row0_col0" class="data row0 col0" >U</td>
#       <td id="T_2c374_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_2c374_row0_col2" class="data row0 col2" >Lower</td>
#       <td id="T_2c374_row0_col3" class="data row0 col3" >2020-12-14</td>
#       <td id="T_2c374_row0_col4" class="data row0 col4" >2.8546</td>
#       <td id="T_2c374_row0_col5" class="data row0 col5" >2020-12-15</td>
#       <td id="T_2c374_row0_col6" class="data row0 col6" >2020-12-14</td>
#       <td id="T_2c374_row0_col7" class="data row0 col7" >4</td>
#     </tr>
#     <tr>
#       <th id="T_2c374_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2c374_row1_col0" class="data row1 col0" >ZR</td>
#       <td id="T_2c374_row1_col1" class="data row1 col1" >True</td>
#       <td id="T_2c374_row1_col2" class="data row1 col2" >Upper</td>
#       <td id="T_2c374_row1_col3" class="data row1 col3" >2020-12-14</td>
#       <td id="T_2c374_row1_col4" class="data row1 col4" >1.6355</td>
#       <td id="T_2c374_row1_col5" class="data row1 col5" >—</td>
#       <td id="T_2c374_row1_col6" class="data row1 col6" >2020-12-14</td>
#       <td id="T_2c374_row1_col7" class="data row1 col7" >4</td>
#     </tr>
#     <tr>
#       <th id="T_2c374_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2c374_row2_col0" class="data row2 col0" >BI</td>
#       <td id="T_2c374_row2_col1" class="data row2 col1" >True</td>
#       <td id="T_2c374_row2_col2" class="data row2 col2" >Lower</td>
#       <td id="T_2c374_row2_col3" class="data row2 col3" >2020-12-14</td>
#       <td id="T_2c374_row2_col4" class="data row2 col4" >1.4985</td>
#       <td id="T_2c374_row2_col5" class="data row2 col5" >2020-12-15</td>
#       <td id="T_2c374_row2_col6" class="data row2 col6" >202

# %% [markdown]
# ## 5. Time-Series Plots
#
# One plot per analyte. Grey band = warning zone, red dashed = failure bounds.
# Orange line = rolling normalised deviation (right-hand axis).
# Orange shading marks the drift period once detected.

# %%
STATUS_COLORS = {
    "Pass"               : "#1565C0",   # blue
    "UpperWarning"       : "#EF6C00",   # orange
    "LowerWarning"       : "#FF8F00",   # amber
    "UpperFailure"       : "#C62828",   # red
    "LowerFailure"       : "#AD1457",   # dark pink
    "IgnoredUpperFailure": "#9E9E9E",   # grey
    "IgnoredLowerFailure": "#BDBDBD",   # light grey
}

def _fmt_date(dt):
    return dt.strftime("%Y-%m-%d") if pd.notna(dt) else "—"


def plot_analyte_drift(adf: pd.DataFrame,
                       analyte: str,
                       std_lot_code: str,
                       drift_info: dict,
                       drift_threshold: float = 0.5) -> None:
    """Time-series plot of measurements coloured by STANDARD_STATUS + rolling normalised deviation."""
    fig, ax1 = plt.subplots(figsize=(14, 5))

    dates = adf["ANALYSED_DATE"]

    # ── Reference values (constant per analyte; take first non-null) ─────────
    def _first(col):
        s = adf[col].dropna() if col in adf.columns else pd.Series(dtype=float)
        return float(s.iloc[0]) if not s.empty else None

    target   = _first("INTERNAL_TARGET_VALUE")
    max_warn = _first("INTERNAL_MAX_WARNING_VALUE")
    min_warn = _first("INTERNAL_MIN_WARNING_VALUE")
    max_fail = _first("INTERNAL_MAX_VALUE")
    min_fail = _first("INTERNAL_MIN_VALUE")

    # Warning band (shaded)
    if max_warn is not None and min_warn is not None:
        ax1.axhspan(min_warn, max_warn, color="#ffe0a0", alpha=0.25, label="Warning zone")

    # Failure bounds
    for val, lbl in [(max_fail, "Failure bound"), (min_fail, None)]:
        if val is not None:
            ax1.axhline(val, color="red", linestyle="--", linewidth=1.0, alpha=0.7,
                        label=lbl if lbl else "_nolegend_")

    # Warning bounds
    for val in [max_warn, min_warn]:
        if val is not None:
            ax1.axhline(val, color="orange", linestyle="-.", linewidth=1.0, alpha=0.9,
                        label="Warning bound" if val == max_warn else "_nolegend_")

    # Target line
    if target is not None:
        ax1.axhline(target, color="#2E7D32", linestyle="-", linewidth=1.5, alpha=0.8,
                    label=f"Target ({target:.3g})")

    # ── Scatter points coloured by STANDARD_STATUS ───────────────────────────
    if "STANDARD_STATUS" in adf.columns:
        plot_df = adf.copy()
        plot_df["STANDARD_STATUS"] = plot_df["STANDARD_STATUS"].fillna("Pass").astype(str)
        present_statuses = plot_df["STANDARD_STATUS"].unique()

        for status in present_statuses:
            grp = plot_df[plot_df["STANDARD_STATUS"] == status]
            color = STATUS_COLORS.get(status, "#607D8B")
            ax1.scatter(grp["ANALYSED_DATE"], grp["NUMERIC_FINAL_VALUE"],
                        s=22, color=color, alpha=0.8, zorder=3, label=status)
    else:
        ax1.scatter(dates, adf["NUMERIC_FINAL_VALUE"],
                    s=22, color="#1565C0", alpha=0.8, zorder=3, label="Pass")

    ax1.set_xlabel("Date")
    ax1.set_ylabel("NUMERIC_FINAL_VALUE")
    ax1.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
    plt.setp(ax1.xaxis.get_majorticklabels(), rotation=30, ha="right")

    # ── Right axis: rolling normalised deviation ──────────────────────────────
    ax2 = ax1.twinx()
    ax2.plot(dates, adf["rolling_norm_dev"],
             color="darkorange", linewidth=2.0, label="Rolling norm. dev.", zorder=2)
    ax2.axhline( drift_threshold, color="darkorange", linestyle=":", linewidth=1.0)
    ax2.axhline(-drift_threshold, color="darkorange", linestyle=":", linewidth=1.0)
    ax2.axhline(0, color="grey", linestyle=":", linewidth=0.8)
    ax2.set_ylabel("Rolling norm. deviation  (0 = target, ±1 = warning bound)")
    ax2.set_ylim(-2.5, 2.5)

    # ── Vertical markers: drift start, first warning, first failure ───────────
    vlines = [
        (drift_info.get("drift_start"),       "red",    "--", 1.8, "Drift start"),
        (drift_info.get("first_warning_date"), "orange", "-.", 1.5, "First warning"),
        (drift_info.get("first_failure_date"), "crimson","-", 1.5, "First failure"),
    ]
    ymax = ax1.get_ylim()[1]

    for dt, color, ls, lw, label in vlines:
        if pd.notna(dt):
            ax1.axvline(dt, color=color, linestyle=ls, linewidth=lw, alpha=0.85, zorder=4)
            ax1.text(dt, ymax, f" {label}\n {_fmt_date(dt)}",
                     color=color, fontsize=7, va="top", rotation=90,
                     bbox=dict(boxstyle="round,pad=0.15", fc="white", alpha=0.6, ec=color))

    # Drift period shading
    if drift_info.get("drift_detected") and pd.notna(drift_info.get("drift_start")):
        ax1.axvspan(drift_info["drift_start"], dates.iloc[-1],
                    color="red", alpha=0.06)

    # ── Legend (left axis handles + right axis rolling line) ─────────────────
    handles1, labels1 = ax1.get_legend_handles_labels()
    rolling_handle = Line2D([0], [0], color="darkorange", linewidth=2, label="Rolling norm. dev.")
    ax1.legend(
        handles1 + [rolling_handle],
        labels1  + ["Rolling norm. dev."],
        loc="upper left", fontsize=8, framealpha=0.85,
        ncol=2
    )

    status_text = (
        f"DRIFT — {drift_info['drift_direction']} | "
        f"Drift start: {_fmt_date(drift_info.get('drift_start'))} | "
        f"First warning: {_fmt_date(drift_info.get('first_warning_date'))} | "
        f"First failure: {_fmt_date(drift_info.get('first_failure_date'))} | "
        f"Severity: {drift_info['severity_score']:.3f}"
        if drift_info.get("drift_detected")
        else (
            f"No drift | "
            f"First warning: {_fmt_date(drift_info.get('first_warning_date'))} | "
            f"First failure: {_fmt_date(drift_info.get('first_failure_date'))} | "
            f"Severity: {drift_info['severity_score']:.3f}"
        )
    )
    title_color = "red" if drift_info.get("drift_detected") else "#2E7D32"
    ax1.set_title(
        f"{std_lot_code} — {analyte}  |  {status_text}",
        fontsize=10, color=title_color, fontweight="bold"
    )

    plt.tight_layout()
    plt.show()

# %%
# ── Plot drifting analytes first, then clean ones ────────────────────────────
for _, row in summary.iterrows():
    analyte   = row["ANALYTE_CODE"]
    adf       = analyte_data[analyte]
    drift_info = row.to_dict()

    plot_analyte_drift(
        adf,
        analyte      = analyte,
        std_lot_code = STD_LOT_CODE,
        drift_info   = drift_info,
        drift_threshold = DRIFT_THRESHOLD,
    )

# %% [markdown]
# ## 6. NEXT STEPS -Sudden Drift detection
# #### Handling of analysing smaller sample sizes
# - The current model needs essentially 13 observations at least in one job of a specific analyte. Because of the rolling mean set on 10 observations and triggering after three consecutive limit breaches. More testing and will be required on smaller observation sizes. This will also incur the possibility  of data retention in the model from previous analysis to concatenate to the most recent data.
#
# #### Introduce point anomaly detection
# - It occurs that certain analytes can have 5 or fewer observations or maybe just one. The mean drift detection won’t be helpful in this case. The goal of this addition is to flag sudden shift instead of a gradual shift.
#
# #### Clear and structured report
# - Build a clear QC chemist readable report of 1-2 lines. Showing when drift began, which upper or lower failure, what kind of drift was detected and on which analyte and job.

# %% [markdown]
# # Drift Detection adjusted filtering

# %%
df_Standard = df[(df["ANALYTICAL_TYPE"] == "Standard")]
print(df_Standard.info())
df_Standard.head(10)
# Out:
# <class 'pandas.DataFrame'>
# Index: 36687 entries, 0 to 99997
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ANALYTICAL_TYPE                 36687 non-null  str
#  1   STD_LOT_CODE                    36687 non-null  str
#  2   STD_CODE                        36687 non-null  str
#  3   JOB_CODE                        36687 non-null  str
#  4   NUMERIC_FINAL_VALUE             36687 non-null  float64
#  5   ANALYSED_DATE                   36687 non-null  datetime64[us]
#  6   SCHEME_CODE                     36687 non-null  str
#  7   ANALYTE_CODE                    36333 non-null  str
#  8   STANDARD_STATUS                 36682 non-null  str
#  9   PRECISION_STATUS                0 non-null      str
#  10  INTERNAL_MIN_VALUE              36450 non-null  float64
#  11  INTERNAL_MAX_VALUE              36450 non-null  float64
#  12  INTERNAL_MIN_INCLUSIVE          36680 non-null  str
#  13  INTERNAL_MAX_INCLUSIVE          36680 non-null  str
#  14  INTERNAL_MAX_WARNING_VALUE      36450 non-null  float64
#  15  INTERNAL_MIN_WARNING_VALUE      36450 non-null  float64
#  16  INTERNAL_MIN_WARNING_INCLUSIVE  36680 non-null  str
#  17  INTERNAL_MAX_WARNING_INCLUSIVE  36680 non-null  str
#  18  LIM_REP_VALUE                   36687 non-null  int64
#  19  STAT_DL_VALUE                   36687 non-null  float64
#  20  LIM_REP_DUP_VALUE               36687 non-null  float64
#  21  STAT_DL_DUP_VALUE               36687 non-null  float64
#  22  INTERNAL_TARGET_VALUE           36448 non-null  float64
#  23  PARENT_NUMERIC_FINAL_VALUE      0 non-null      float64
#  24  UNIT_CODE                       36687 non-null  str
#  25  SPECIFICATION_CODE              36686 non-null  str
#  26  INSTRUMENT_ID                   0 non-null      str
# dtypes: datetime64[us](1), float64(10), int64(1), str(15)
# memory usage: 10.7 MB
# None
#    ANALYTICAL_TYPE STD_LOT_CODE   STD_CODE          JOB_CODE  NUMERIC_FINAL_VALUE       ANALYSED_DATE  SCHEME_CODE ANALYTE_CODE      STANDARD_STATUS  \
# 0         Standard    OREAS_905  OREAS_905  TSV_LB0016663011            35.927171 2021-11-22 16:37:52  GE_IMS40Q12           PB         UpperFailure
# 1         Standard    OREAS_905  OREAS_905  TSV_LB0016663011            55.639610 2021-11-22 16:37:52  GE_IMS40Q12           PB         UpperFailure
# 4         Standard    OREAS_905  OREAS_905  TSV_LB0016663011            11.742601 2021-11-22 16:37:33  GE_IMS40Q12           NI         UpperWarning
# 5         Standard    OREAS_905  OREAS_905  TSV_LB0016663011            12.236060 2021-11-22 16:37:33  GE_IMS40Q12           NI         UpperFailure
# 7         Standard    OREAS_905  OREAS_905  TSV_LB0016663011          1501.882410 2021-11-22 16:35:49  GE_IMS40Q12           CU                 Pass
# 8         Standard    OREAS_905  OREAS_905  TSV_LB0016663011          1550.868306 2021-11-22 16:35:49  GE_IMS40Q12           CU                 Pass
# 10        Standard    OREAS_905  OREAS_905  TSV_LB0016663011             1.093424 2021-11-22 16:35:49  GE_IMS40Q12           AG  IgnoredUpperFailure
# 11        Standard    OREAS_905  OREAS_905  TSV_LB0016663011           162.756679 2021-11-22 16:35:49  GE_IMS40Q12           ZN  IgnoredUpperFailure
# 12        Standard    OREAS_905  OREAS_905  TSV_LB0016663011             0.705665 2021-11-22 16:35:49  GE_IMS40Q12           AG         UpperFailure
# 13        Standard    OREAS_905  OREAS_905  TSV_LB0016663011           143.443845 2021-11-22 16:35:49  GE_IMS40Q12           ZN                 Pass
#
#    PRECISION_STATUS  INTERNAL_MIN_VALUE  INTERNAL_MAX_VALUE INTERNAL_MIN_INCLUSIVE INTERNAL_MAX_INCLUSIVE  INTERNAL_MAX_WARNING_VALUE  \
# 0               NaN           26.110560           34.689440                      Y                      Y                   33.120800
# 1               NaN           26.110560           34.689440                      Y                      Y                   33.120800
# 4               NaN            7.336260           11.743740                      Y                      Y                   10.937610
# 5               NaN            7.336260           11.743740                      Y                      Y                   10.937610
# 7               NaN         1379.700000         1686.300000                      Y                      Y                 1630.192200
# 8               NaN         1379.700000         1686.300000                      Y                      Y                 1630.192200
# 10              NaN            0.416213            0.619787                      Y                      Y                    0.582543
# 11              NaN          124.144800          151.855200                      Y                      Y                  146.790600
# 12              NaN            0.416213            0.619787                      Y                      Y                    0.582543
# 13              NaN          124.144800          151.855200                      Y                      Y                  146.790600
#
#     INTERNAL_MIN_WARNING_VALUE INTERNAL_MIN_WARNING_INCLUSIVE INTERNAL_MAX_WARNING_INCLUSIVE  LIM_REP_VALUE  STAT_DL_VALUE  LIM_REP_DUP_VALUE  \
# 0                    27.679200                              Y                              Y             10           1.25               15.0
# 1                    27.679200                              Y                              Y             10           1.25               15.0
# 4                     8.142390                              Y                              Y             10           5.00               15.0
# 5                     8.142390                              Y                              Y             10           5.00               15.0
# 7                  1435.807800                              Y                              Y             10           5.00               15.0
# 8                  1435.807800                              Y                              Y             10           5.00               15.0
# 10                    0.453457                              Y                              Y             10           0.05               15.0
# 11                  129.209400                              Y                              Y             10          12.50               15.0
# 12                    0.453457                              Y                              Y             10           0.05               15.0
# 13                  129.209400                              Y                              Y             10          12.50               15.0
#
#     STAT_DL_DUP_VALUE  INTERNAL_TARGET_VALUE  PARENT_NUMERIC_FINAL_VALUE UNIT_CODE SPECIFICATION_CODE INSTRUMENT_ID
# 0                1.25                 30.400                         NaN     MG_KG          OREAS_905           NaN
# 1                1.25                 30.400                         NaN     MG_KG          OREAS_905           NaN
# 4                5.00                  9.540                         NaN     MG_KG          OREAS_905           NaN
# 5                5.00                  9.540                         NaN     MG_KG          OREAS_905           NaN
# 7                5.00               1533.000                         NaN     MG_KG          OREAS_905           NaN
# 8                5.00               1533.000                         NaN     MG_KG          OREAS_905           NaN
# 10               0.05                  0.518                         NaN     MG_KG          OREAS_905           NaN
# 11              12.50                138.000                         NaN     MG_KG          OREAS_905           NaN
# 12               0.05                  0.518                         NaN     MG_KG          OREAS_905           NaN
# 13              12.50                138.000                         NaN     MG_KG          OREAS_905           NaN

# %%
print(df_Standard["STD_LOT_CODE"].value_counts().to_string())
# Out:
# STD_LOT_CODE
# Sample        6958
# OREAS_905     5661
# OREAS_62F     5551
# OREAS_501C    5410
# OREAS_503C    4305
# OREAS_624     4299
# OREAS_522     1122
# OREAS_139     1013
# OREAS_908      735
# OREAS_524      519
# OREAS_503D     225
# OREAS_351      205
# OREAS_20A      164
# OREAS_98       157
# OREAS_623      136
# OREAS_621       61
# OREAS_505       58
# OREAS_520       26
# OREAS_136       25
# OREAS_38        21
# OREAS_45F       10
# OREAS_45H       10
# OREAS_622       10
# OREAS_605        6

# %% [markdown]
# ## visualising sub groups

# %%
# ── INPUT ────────────────────────────────────────────────────────────────────
STD_LOT_CODE = "OREAS_905"   
print(df_Standard[df_Standard["STD_LOT_CODE"] == STD_LOT_CODE]["JOB_CODE"].value_counts().to_string())
# Out:
# JOB_CODE
# TSV_LB0005394796    172
# TSV_LB0005186285    172
# TSV_LB0005186144    172
# TSV_LB0004988884    172
# TSV_LB0006066326    170
# TSV_LB0005485209    142
# TSV_LB0008323905     95
# TSV_LB0006065977     86
# TSV_LB0006065731     86
# TSV_LB0005815864     86
# TSV_LB0005394901     86
# TSV_LB0005816034     84
# TSV_LB0000666551     69
# TSV_LB0006205235     58
# TSV_LB0004023226     57
# TSV_LB0008614636     48
# TSV_LB0008259837     48
# TSV_LB0006515826     48
# TSV_LB0005725239     48
# TSV_LB0004440213     48
# TSV_LB0004373671     48
# TSV_LB0003759685     48
# TSV_LB0002964317     48
# TSV_LB0002943407     48
# TSV_LB0002861340     48
# TSV_LB0000449085     45
# TSV_LB0012748553     41
# TSV_LB0011831883     41
# TSV_LB0013181376     39
# TSV_LB0013180653     39
# TSV_LB0012717232     39
# TSV_LB0012715799     39
# TSV_LB0011555855     39
# TSV_LB0011017343     39
# TSV_LB0009897062     39
# TSV_LB0011555967     37
# TSV_LB0014380676     36
# TSV_LB0010355280     31
# TSV_LB0011700166     29
# TSV_LB0014380208     26
# TSV_LB0014379618     26
# TSV_LB0013181636     26
# TSV_LB0013182767     26
# TSV_LB0011831593     13
# TSV_LB0011738609     13
# TSV_LB0011556391     13
# TSV_LB0011555637     13
# TSV_LB0010598601     13
# TSV_LB0010174736     13
# TSV_LB0010598424     13
# TSV_LB0010597947     13
# TSV_LB0010436333     13
# TSV_LB0010174847     13
# TSV_LB0010436456     13
# TSV_LB0010355576     13
# TSV_LB0010174404     13
# TSV_LB0009897335     13
# TSV_LB0009897223     13
# TSV_LB0009896894     13
# TSV_LB0009122165     13
# TSV_LB0008614586     13
# TSV_LB0008056389     13
# TSV_LB0007441984     13
# TSV_LB0007441872     13
# TSV_LB0006489478     13
# TSV_LB0006260491     13
# TSV_LB0005348874     13
# TSV_LB0004308960     13
# TSV_LB0003855762     13
# TSV_LB0002964538     13
# TSV_LB0002728540     13
# TSV_LB0013193412     12
# TSV_LB0010355804     12
# TSV_LB0002920370     11
# TSV_LB0016663011     10
# TSV_LB0010355698     10
# TSV_LB0010355391      9
# TSV_LB0012716696      8
# TSV_LB0011327547      7
# TSV_LB0002629103      7
# TSV_LB0002610232      6
# TSV_LB0011555742      4
# TSV_LB0010012124      2
# TSV_LB0009506639      2
# TSV_LB0006906893      2
# TSV_LB0004839668      2
# TSV_LB0011005475      1
# TSV_LB0009932202      1
# TSV_LB0008819102      1
# TSV_LB0004622664      1
# TSV_LB0004521920      1
# TSV_LB0003617921      1
# TSV_LB0003291263      1
# TSV_LB0003119185      1

# %%
# ── INPUT ────────────────────────────────────────────────────────────────────
JOB_CODE = 'TSV_LB0008323905'

df_Standard_job = df_Standard[df_Standard['JOB_CODE'] == JOB_CODE]
print(df_Standard_job["STANDARD_STATUS"].value_counts().to_string())
# Out:
# STANDARD_STATUS
# Pass                   95
# UpperWarning           17
# LowerWarning            9
# LowerFailure            9
# UpperFailure            6
# IgnoredLowerFailure     4
# IgnoredUpperFailure     1

# %%
df_Standard_job = df_Standard_job[df_Standard_job['STD_LOT_CODE'] == STD_LOT_CODE]
df_Standard_job.head(5)
# Out:
#       ANALYTICAL_TYPE STD_LOT_CODE   STD_CODE          JOB_CODE  NUMERIC_FINAL_VALUE       ANALYSED_DATE  SCHEME_CODE ANALYTE_CODE      STANDARD_STATUS  \
# 27268        Standard    OREAS_905  OREAS_905  TSV_LB0008323905             4.735275 2021-04-14 12:09:26  GE_IMS40Q12           BI  IgnoredLowerFailure
# 27269        Standard    OREAS_905  OREAS_905  TSV_LB0008323905             4.378956 2021-04-14 12:09:26  GE_IMS40Q12           BI  IgnoredLowerFailure
# 27275        Standard    OREAS_905  OREAS_905  TSV_LB0008323905             4.795293 2021-04-14 12:09:25  GE_IMS40Q12           BI  IgnoredLowerFailure
# 27278        Standard    OREAS_905  OREAS_905  TSV_LB0008323905           133.043481 2021-04-14 08:29:31  GE_IMS40Q12           ZN                 Pass
# 27279        Standard    OREAS_905  OREAS_905  TSV_LB0008323905           135.023926 2021-04-14 08:29:31  GE_IMS40Q12           ZN                 Pass
#
#       PRECISION_STATUS  INTERNAL_MIN_VALUE  INTERNAL_MAX_VALUE INTERNAL_MIN_INCLUSIVE INTERNAL_MAX_INCLUSIVE  INTERNAL_MAX_WARNING_VALUE  \
# 27268              NaN              5.0479              6.3921                      Y                      Y                     6.14614
# 27269              NaN              5.0479              6.3921                      Y                      Y                     6.14614
# 27275              NaN              5.0479              6.3921                      Y                      Y                     6.14614
# 27278              NaN            124.1448            151.8552                      Y                      Y                   146.79060
# 27279              NaN            124.1448            151.8552                      Y                      Y                   146.79060
#
#        INTERNAL_MIN_WARNING_VALUE INTERNAL_MIN_WARNING_INCLUSIVE INTERNAL_MAX_WARNING_INCLUSIVE  LIM_REP_VALUE  STAT_DL_VALUE  LIM_REP_DUP_VALUE  \
# 27268                     5.29386                              Y                              Y             10            0.1               15.0
# 27269                     5.29386                              Y                              Y             10            0.1               15.0
# 27275                     5.29386                              Y                              Y             10            0.1               15.0
# 27278                   129.20940                              Y                              Y             10           12.5               15.0
# 27279                   129.20940                              Y                              Y             10           12.5               15.0
#
#        STAT_DL_DUP_VALUE  INTERNAL_TARGET_VALUE  PARENT_NUMERIC_FINAL_VALUE UNIT_CODE SPECIFICATION_CODE INSTRUMENT_ID
# 27268                0.1                   5.72                         NaN     MG_KG          OREAS_905           NaN
# 27269                0.1                   5.72                         NaN     MG_KG          OREAS_905           NaN
# 27275                0.1                   5.72                         NaN     MG_KG          OREAS_905           NaN
# 27278               12.5                 138.00                         NaN     MG_KG          OREAS_905           NaN
# 27279               12.5                 138.00                         NaN     MG_KG          OREAS_905           NaN

# %%
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(data=df_Standard_job, x='NUMERIC_FINAL_VALUE', hue='STANDARD_STATUS', bins=110)
plt.title('Distribution of NUMERIC_FINAL_VALUE for Job: ' + JOB_CODE)
# plot a vertical line for INTERNAL_MIN_VALUE and INTERNAL_MAX_VALUE
plt.axvline(x=df_Standard_job['INTERNAL_MIN_VALUE'].iloc[0], color='red', linestyle='--', label='Internal Min')
plt.axvline(x=df_Standard_job['INTERNAL_MAX_VALUE'].iloc[0], color='blue', linestyle='--', label='Internal Max')
plt.xlabel('NUMERIC_FINAL_VALUE')
# Out:
# Text(0.5, 0, 'NUMERIC_FINAL_VALUE')

# %%
# ── Per-row scale transform ────────────────────────────────────────────────
# Maps INTERNAL_MIN_VALUE -> -1, INTERNAL_TARGET_VALUE -> 0, INTERNAL_MAX_VALUE -> 1
# (piecewise-linear per row, since target need not sit midway between min and max).
# NUMERIC_FINAL_VALUE and the warning bounds are carried through the same per-row
# scale factors, so e.g. a value halfway between target and max lands at 0.5.
scale_cols = [
    "NUMERIC_FINAL_VALUE", "INTERNAL_MAX_VALUE", "INTERNAL_MIN_VALUE",
    "INTERNAL_MAX_WARNING_VALUE", "INTERNAL_MIN_WARNING_VALUE", "INTERNAL_TARGET_VALUE",
]

df_trans = df_Standard_job.copy()

target = df_trans["INTERNAL_TARGET_VALUE"]
upper_scale = (df_trans["INTERNAL_MAX_VALUE"] - target).replace(0, np.nan)
lower_scale = (target - df_trans["INTERNAL_MIN_VALUE"]).replace(0, np.nan)

for col in scale_cols:
    val = df_trans[col]
    df_trans[f"{col}_scaled"] = np.where(
        val >= target,
        (val - target) / upper_scale,
        (val - target) / lower_scale,
    )

df_trans[scale_cols + [f"{c}_scaled" for c in scale_cols]].head(10)
# Out:
#        NUMERIC_FINAL_VALUE  INTERNAL_MAX_VALUE  INTERNAL_MIN_VALUE  INTERNAL_MAX_WARNING_VALUE  INTERNAL_MIN_WARNING_VALUE  INTERNAL_TARGET_VALUE  \
# 27268             4.735275            6.392100            5.047900                    6.146140                    5.293860                  5.720
# 27269             4.378956            6.392100            5.047900                    6.146140                    5.293860                  5.720
# 27275             4.795293            6.392100            5.047900                    6.146140                    5.293860                  5.720
# 27278           133.043481          151.855200          124.144800                  146.790600                  129.209400                138.000
# 27279           135.023926          151.855200          124.144800                  146.790600                  129.209400                138.000
# 27281             0.039234            0.221804           -0.045804                    0.172876                    0.003124                  0.088
# 27284             0.041546            0.221804           -0.045804                    0.172876                    0.003124                  0.088
# 27287             0.066981            0.221804           -0.045804                    0.172876                    0.003124                  0.088
# 27291           133.301889          151.855200          124.144800                  146.790600                  129.209400                138.000
# 27296             2.189474            2.269995            1.630005                    2.152995                    1.747005                  1.950
#
#        NUMERIC_FINAL_VALUE_scaled  INTERNAL_MAX_VALUE_scaled  INTERNAL_MIN_VALUE_scaled  INTERNAL_MAX_WARNING_VALUE_scaled  INTERNAL_MIN_WARNING_VALUE_scaled  \
# 27268                   -1.465146                        1.0                       -1.0                           0.634043                          -0.634043
# 27269                   -1.995304                        1.0                       -1.0                           0.634043                          -0.634043
# 27275                   -1.375848                        1.0                       -1.0                           0.634043                          -0.634043
# 27278                   -0.357737                        1.0                       -1.0                           0.634462                          -0.634462
# 27279                   -0.214798                        1.0                       -1.0                           0.634462                          -0.634462
# 27281                   -0.364455                        1.0                       -1.0                           0.634331                          -0.634331
# 27284                   -0.347180                        1.0                       -1.0                           0.634331                          -0.634331
# 27287                   -0.157087                        1.0                       -1.0                           0.634331                          -0.634331
# 27291                   -0.339086                        1.0                       -1.0                           0.634462                          -0.634462
# 27296                    0.748367                        1.0                       -1.0                           0.634369                          -0.634369
#
#        INTERNAL_TARGET_VALUE_scaled
# 27268                           0.0
# 27269                           0.0
# 27275                           0.0
# 27278                           0.0
# 27279                           0.0
# 27281                           0.0
# 27284                           0.0
# 27287                           0.0
# 27291                           0.0
# 27296                           0.0

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df_trans, x='NUMERIC_FINAL_VALUE', hue='STANDARD_STATUS', bins=110)
plt.title('Distribution of NUMERIC_FINAL_VALUE for Job: ' + JOB_CODE)
# plot a vertical line for INTERNAL_MIN_VALUE and INTERNAL_MAX_VALUE
plt.axvline(x=df_trans['INTERNAL_MIN_VALUE'].iloc[0], color='red', linestyle='--', label='Internal Min')
plt.axvline(x=df_trans['INTERNAL_MAX_VALUE'].iloc[0], color='blue', linestyle='--', label='Internal Max')
plt.xlabel('NUMERIC_FINAL_VALUE')
# Out:
# Text(0.5, 0, 'NUMERIC_FINAL_VALUE')
